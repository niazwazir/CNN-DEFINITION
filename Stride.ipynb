# %%
from keras.models import Sequential
from keras.layers import Conv2D
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0861ae82-8dc4-497c-87e5-eac0e394f024" name="files[]" multiple disabled />
#      <output id="result-0861ae82-8dc4-497c-87e5-eac0e394f024">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Paddingd.png to Paddingd.png
# ...

# %%
from IPython.display import Image
Image('Padding.png')

# %%
model = Sequential()
model.add(Conv2D(1,(3,3), activation='relu', input_shape = (32,32,1)))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_2 (Conv2D)            (None, 30, 30, 1)         10
# ...
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________

# %%
SVG(model_to_dot(model, show_shapes=True).create(prog='dot',format='svg'))

# %%
from IPython.display import Image
Image('Paddinga.png')

# %%
model = Sequential()
model.add(Conv2D(1,(3,3), padding = 'valid',activation='relu', input_shape = (32,32,1)))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 30, 30, 1)         10
# ...
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________

# %%
from IPython.display import Image
Image('Paddingc.png')

# %%
model = Sequential()
model.add(Conv2D(1,(3,3), padding = 'same',activation='relu', input_shape = (32,32,1)))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 32, 32, 1)         10
# ...
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________

# %%
from IPython.display import Image
Image('Paddingd.png')

# %%
model = Sequential()
model.add(Conv2D(1,(3,3), strides = (2,2), padding = 'same',activation='relu', input_shape = (32,32,1)))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7 (Conv2D)            (None, 16, 16, 1)         10
# ...
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________
