# %%
#FIRST OF ALL CHANGE BACKEND FROM TENSORFLOW TO THEANO
#BECAUSE FULLPADDING IS WORK IN KERAS USING BACKEND AS THEANO
import os
os.environ["KERAS_BACKEND"] = "theano"
import keras; import keras.backend
if keras.backend.backend() != 'theano':
    raise BaseException("This script uses other backend")
else:
    keras.backend.set_image_dim_ordering('th')
    print("Backend ok")
# Out:
# Using Theano backend.
# Backend ok

# %%
from IPython.display import Image
Image('PADDING_FULL.png')

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %%
model = Sequential()
model.add(Conv2D(1,(3,3), padding = 'full',activation='relu', input_shape = (1,28,28)))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_15 (Conv2D)           (None, 1, 30, 30)         10
# ...
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = Sequential()
model.add(Conv2D(1,(5,5), padding = 'full',activation='relu', input_shape = (1,28,28)))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_16 (Conv2D)           (None, 1, 32, 32)         26
# ...
# Total params: 26
# Trainable params: 26
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = Sequential()
model.add(Conv2D(1,(7,7), padding = 'full',activation='relu', input_shape = (1,28,28)))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_17 (Conv2D)           (None, 1, 34, 34)         50
# ...
# Total params: 50
# Trainable params: 50
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = Sequential()
model.add(Conv2D(1,(9,9), padding = 'full',activation='relu', input_shape = (1,28,28)))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_18 (Conv2D)           (None, 1, 36, 36)         82
# ...
# Total params: 82
# Trainable params: 82
# Non-trainable params: 0
# _________________________________________________________________
