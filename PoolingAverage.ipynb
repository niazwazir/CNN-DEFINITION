# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f38c12e9-7139-4cb5-93e3-999435522436" name="files[]" multiple disabled />
#      <output id="result-f38c12e9-7139-4cb5-93e3-999435522436">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Average.png to Average.png

# %%
#MaxPooling Layer
from IPython.display import Image
Image('Average.png')

# %%
from keras.models import Sequential
from keras.layers import Conv2D, AveragePooling2D,MaxPooling2D
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %%
model = Sequential()
model.add( Conv2D(10, (3,3), padding= 'same',input_shape=(26,26,1)) )
model.add(AveragePooling2D(pool_size=(2,2)))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 26, 26, 10)        100
# _________________________________________________________________
# average_pooling2d_6 (Average (None, 13, 13, 10)        0
# =================================================================
# Total params: 100
# Trainable params: 100
# Non-trainable params: 0
# _________________________________________________________________

# %%
SVG(model_to_dot(model, show_shapes=True).create(prog='dot',format='svg'))
