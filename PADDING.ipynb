# %% [markdown]
# PADDING
#
# TYPES OF PADDING
# There are two types of Padding:
#
# 1)	Valid Padding (No Padding), so your input size is not maintain.
#
# 2)	Same Padding (means we pad with number on edge) so O/P Image Size is same as I/P Image Size
#
# ZERO PADDING
# Add the zeros on the edges so due to this is called as Zero Padding.
#
#
# HOW TO SOLVE SHRINKING PROBLEM IN CNN
#
# So every time you apply convolution your image is going to shrink.
# To solve this issue we use Padding on the border of the image

# %%
from  IPython.display  import Image
Image('A.png')

# %%
from  IPython.display  import Image
Image('C.png')

# %%
from  IPython.display  import Image
Image('B.png')

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Activation
import keras.backend as K
from keras import optimizers
import numpy as np

import keras
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense, Flatten
# Out:
# C:\Users\niaz\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model_valid = Sequential([
    Dense(16, activation='relu', input_shape=(20,20,3)),
    Conv2D(32, kernel_size=(3,3),activation='relu',padding='valid'),
    Conv2D(64, kernel_size=(5,5),activation='relu',padding='valid'),
    Conv2D(128, kernel_size=(7,7),activation='relu',padding='valid'),
    Flatten(),
    Dense(2,activation='softmax'),
    
])

# %%
model_valid.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 20, 20, 16)        64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 18, 32)        4640
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        51264
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         401536
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 16386
# ...
# Total params: 473,890
# Trainable params: 473,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_valid = Sequential([
    Dense(16, activation='relu', input_shape=(20,20,3)),
    Conv2D(32, kernel_size=(3,3),activation='relu',padding='same'),
    Conv2D(64, kernel_size=(5,5),activation='relu',padding='same'),
    Conv2D(128, kernel_size=(7,7),activation='relu',padding='same'),
    Flatten(),
    Dense(2,activation='softmax'),
    
])

# %%
model_valid.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 20, 20, 16)        64
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 20, 20, 32)        4640
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 20, 20, 64)        51264
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 20, 20, 128)       401536
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 102402
# ...
# Total params: 559,906
# Trainable params: 559,906
# Non-trainable params: 0
# _________________________________________________________________
