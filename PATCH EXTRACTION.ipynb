# %% [markdown]
# PATCH EXTRACTION

# %%
from  IPython.display  import Image
Image('A.png')

# %%
from  IPython.display  import Image
Image('B.png')

# %%
from  IPython.display  import Image
Image('C.png')

# %%
from  IPython.display  import Image
Image('E.png')
