# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1de239c2-308d-4bb2-afac-22f8996c7bf4" name="files[]" multiple disabled />
#      <output id="result-1de239c2-308d-4bb2-afac-22f8996c7bf4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Pooling1.png to Pooling1.png

# %%
#MaxPooling Layer
from IPython.display import Image
Image('Pooling1.png')

# %%
#MaxPooling Layer
from IPython.display import Image
Image('MaxPooling.png')

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %%
model = Sequential()
model.add( Conv2D(10, (3,3), padding= 'same',input_shape=(26,26,1)) )
model.add( MaxPooling2D(pool_size=(2,2)) )
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 26, 26, 10)        730
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 10)        0
# =================================================================
# Total params: 730
# Trainable params: 730
# Non-trainable params: 0
# _________________________________________________________________

# %%
SVG(model_to_dot(model, show_shapes=True).create(prog='dot',format='svg'))
